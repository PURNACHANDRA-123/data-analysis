# %%
#pandas will useful for data processing analysis
#pandas data frame is 2d tabular data structure with labeled axes(rows and col)
import pandas as pd
import numpy as np

# %%
#importing the boston house price data
from sklearn.datasets import fetch_california_housing #Make sure this line is executed before calling fetch_california_housing()

# %%
housing_data = fetch_california_housing()
type(housing_data)
print(housing_data)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
#pandas dataframe work
housing_dt=pd.DataFrame(housing_data.data,columns=housing_data.feature_names)
housing_dt.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
housing_dt.shape
# Out:
# (20640, 8)

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Paris', 'Berlin', 'Tokyo']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    Berlin
# 3    David   40     Tokyo

# %%
#importing data from csv file to pandas dataframework
diabetes=pd.read_csv('/content/diabetes.csv')

type(diabetes)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes.head()
#diabetes.shape
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Loading the data from a excel file to a Pandas DataFrame:  pd.read_excel('file path')
#Exporting a DataFrame to a csv file
housing_dt.to_csv('housing_data.csv')

# %%
#Exporting the Pandas DataFrame to an excel File:
#df.to_excel('filename')

housing_dt.to_excel('housing.xlsx') # Added '.xlsx' to specify file type

# %%
#creating a dataframe with random value
random_df=pd.DataFrame(np.random.rand(20,10))
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.215348  0.702435  0.595885  0.385390  0.894214  0.380228  0.224648
# 1  0.866722  0.843961  0.808884  0.517343  0.614684  0.683361  0.897916
# 2  0.599326  0.166365  0.576580  0.185574  0.814555  0.619624  0.711113
# 3  0.274705  0.260236  0.952266  0.878475  0.105243  0.358176  0.827890
# 4  0.109678  0.871928  0.919379  0.431572  0.321318  0.845865  0.373666
#
#           7         8         9
# 0  0.697505  0.284123  0.968569
# 1  0.906035  0.431635  0.080084
# 2  0.910726  0.813803  0.767899
# 3  0.794485  0.485032  0.806761
# 4  0.225835  0.589753  0.627761

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#inspecting dataframe
random_df.info()
#last 5 rows of dataframe
random_df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float64
#  1   1       20 non-null     float64
#  2   2       20 non-null     float64
#  3   3       20 non-null     float64
#  4   4       20 non-null     float64
#  5   5       20 non-null     float64
#  6   6       20 non-null     float64
#  7   7       20 non-null     float64
#  8   8       20 non-null     float64
#  9   9       20 non-null     float64
# dtypes: float64(10)
# memory usage: 1.7 KB
#            0         1         2         3         4         5         6  \
# 15  0.341232  0.108665  0.784698  0.483759  0.954070  0.789193  0.455355
# 16  0.329638  0.670841  0.353509  0.197451  0.177268  0.095549  0.797121
# 17  0.415392  0.431569  0.663801  0.461441  0.322672  0.009117  0.600958
# 18  0.446958  0.660892  0.901011  0.718856  0.785922  0.657282  0.111477
# ...

# %%
#finding the number of missing values
random_df.isnull().sum()
housing_dt.isnull().sum()
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#counting the values based on the labels
diabetes.value_counts('Insulin')
diabetes.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#group the value
diabetes.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#statistical meacures #count number of values
housing_dt.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
#mean value value co wise
diabetes.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#Standard deviation measures how spread out the data points are from the mean (average) of a column. A higher standard deviation indicates greater variability, while a lower standard deviation indicates data points are clustered closer to the mean.
diabetes.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#min value
diabetes.min()
diabetes.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
#adding a column to dataframe
housing_dt['Price']=housing_data.target
housing_dt.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
diabetes["succes ratio"]=diabetes["Outcome"]/diabetes["Pregnancies"]
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  succes ratio
# 0                     0.627   50        1      0.166667
# 1                     0.351   31        0      0.000000
# 2                     0.672   32        1      0.125000
# 3                     0.167   21        0      0.000000
# 4                     2.288   33        1           inf

# %%
#removing row
random_df.drop(index=0,axis=0) # axis 0 means rows as per index
#drop a col
random_df.drop(columns=0,axis=1) #colums axis=for col
#yuo having mention col name in case string
diabetes.drop(columns='succes ratio',axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#locating a particular col
diabetes.iloc[:,0]  #1st column
random_df.iloc[:,0]
# Out:
# 0     0.215348
# 1     0.866722
# 2     0.599326
# 3     0.274705
# 4     0.109678
# 5     0.257808
# 6     0.936330
# 7     0.980523
# 8     0.013598
# 9     0.441172
# 10    0.236726
# 11    0.124099
# 12    0.755704
# 13    0.131337
# 14    0.742517
# 15    0.341232
# 16    0.329638
# 17    0.415392
# 18    0.446958
# 19    0.021582
# Name: 0, dtype: float64

# %%
#locating a row
diabetes.iloc[0,:] #1st row
random_df.iloc[0,:]
# Out:
# 0    0.215348
# 1    0.702435
# 2    0.595885
# 3    0.385390
# 4    0.894214
# 5    0.380228
# 6    0.224648
# 7    0.697505
# 8    0.284123
# 9    0.968569
# Name: 0, dtype: float64

# %%
#correaltion = +/- correaltion
diabetes.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
# succes ratio                -0.188576  0.316214       0.044422       0.138472
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# ...

# %%
# psotivit correaltion
housing_dt.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
